# %%
name = input()
print("Hello:",name)
# Out:
# Hello: uet

# %% [markdown]
# ### Bài 1: Nhập vào số nguyên n, in ra màn hình số gấp đôi của n

# %%
n = int(input())
print(2*n)
# Out:
# 6

# %% [markdown]
# ### Bài 2:
# Một khu đất hình chữ nhật có chiều rộng a, chiều dài b. Người ra xây một khu
# vui chơi hình tròn tại vị trí trung tâm khu đất như hình vẽ. Nhập vào a, b. Hãy tính phần
# diện tích còn để trồng cây xung quanh là bao nhiêu. Biết pi = 3.14, lấy kết quả đến 2
# chữ số phần thập phân.

# %%
a= int(input())
b= int(input())
Pi= 3.14
tron=(a/2)**2*Pi
if 0<a<b:
 Dientich=(a*b-tron)
else:
 Dientich=False
print(f"{Dientich}")
# Out:
# 162.95999999999998

# %% [markdown]
# ### Bài 3:
# Viết chương trình nhập vào một “kí tự” c, nếu nó là chữ hoa thì in ra chữ thường
# tương ứng và ngược lại nếu nó là chữ thường thì in ra chữ hoa tương ứng của nó. (xem
# trước cấu trúc lựa chọn: if….else, ma)

# %%
c= input()
if c.isupper():
 print(c.lower())
if c.islower():
 print(c.upper())
# Out:
# r

# %%
c= input()
print(c.swapcase())
# Out:
# nGOOC

# %% [markdown]
# ### Bài 4:
# Viết chương trình nhập vào một “kí tự”, Kiểm tra xem c có phải là kí tự chữ cái
# không (hoa hoặc thường). Nếu đúng thì in ra “{c} là kí tu alphabet”, nếu sai in ra “{c}
# không phải là kí tự alphabet.

# %%
c = input()
if len(c)==1:
 if c.isalpha():
    print(f"{c} là kí tự alphabet")
 else:
    print(f"{c} không phải kí tự alphabet")
else:
  print("LỖI RỒI, đồ nger!!!")
# Out:
# 3 không phải kí tự alphabet

# %% [markdown]
# ### Bài 5:
# Nhập vào chữ cái hoa A, in ra chữ cái thường liền trước chữ cái a thường tương
# ứng của A. Xét TH khi c = ‘A’ là đặc biệt.

# %%
c = input()
if c.isalpha() and c.isupper() and len(c)==1:
 x=c.lower()
 chuyenvedoidau= ord(x)
 ketquane= chr(chuyenvedoidau-1)
 print(f"{ketquane} là thứ m nhận được")
if c == "A":
 print("A là trường hợp đặc biệt!!!")
else:
 print("nhập chữ cái in hoa dùm")
# Out:
# ` là thứ m nhận được
# nhập chữ cái in hoa dùm

# %% [markdown]
# ### Bài 6.
# Nhập vào 3 số a, b, c. Kiểm tra xem đây có phải là cạnh của 1 tam giác không,
# nếu đúng thì tính diện tích của tam giác đó, in ra với 1 chữ số phần thập phân, nếu nó
# không phải 3 cạnh của tam giác thì in ra “Khong phai 3 canh cua tam giac”.

# %%
import math
a = float(input())
b = float(input())
c = float(input())
if 0<a and 0<b and 0<c and a + b > c and a + c > b and b + c > a:
    p = (a+b+c)/2
    s = math.sqrt(p*(p-a)*(p-b)*(p-c))
    print(f"diện tích tam giác là : {s:.1f}")
else:
    print("Khong phai 3 canh cua tam giac")
# Out:
# diện tích tam giác là : 14.7

# %% [markdown]
# ### Bài 7:
#  Nhập vào một chuỗi gồm các kí tự thường độ dài >=20, in ra chữ cái thứ năm và thứ chín của chuỗi này.

# %%
a = input()
if len(a)>=20 and a.isalpha and a.islower:
 chucaithu5=a[4]
 chucaithu9=a[8] 
 print(f"Trong '{a}' chữ cái thứ 5 là : {chucaithu5} và chữ cái thứ 9 là : {chucaithu9}")
else:
 print("nhập a là một chuỗi gồm các kí tự thường độ dài >=20")
# Out:
# Trong 'i take a look at you' chữ cái thứ 5 là : k và chữ cái thứ 9 là :

# %% [markdown]
# ### Bài 8:
# Nhập vào họ tên chủ hộ và chỉ số điện kế tháng trước và chỉ số điện kế tháng này, tính tiền điện tháng này cho hộ

# %%
a = input("Nhập tên chủ hộ:")
b = int(input("Chỉ số điện kế tháng trước:"))
c = int(input("Chỉ số điện kế tháng này:"))
print(f"Ho va ten:{a}")
d = c - b
if d<0:
    print("Nhập sai")
else:
    if 0<=d<=50:
        T= d * 1984
    elif 51<=d<=100:
        T = 50*1984 + (d-50)*2050
    elif 101<=d<=200:
        T = 50*1984 + 50*2050 + (d-100)*2380
    elif 201<=d<=300:
        T = 50*1984 + 50*2050 + 100*2380 + (d-200)*2998
    elif 301<=d<=400:
        T = 50*1984 + 50*2050 + 100*2380 + 100*2998 + (d-300)*3350
    else:
        T = 50*1984 + 50*2050 + 100*2380 + 100*2998 + 100*3350 + (d-400)*3460
    tien=int(T*1.08)
    print(f"Tien phai tra la:{tien}")
