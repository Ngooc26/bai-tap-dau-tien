# %% [markdown]
# ## W3A1
# Viết một chương trình nhập vào một số nguyên n và in ra các chữ số đảo ngược nhau.

# %% [markdown]
# ###### ten_bien[start:stop:step] và slicing chỉ hoạt động trên chuỗi hoặc danh sách

# %%
a = int(input())
b = int(str(a)[6::-1])
print(b)
# Out:
# 7654321

# %% [markdown]
# ###### reverse() chỉ hoạt động với danh sách, không hoạt động trực tiếp với số hay chuỗi

# %%
a = input()
b = list(a)
b.reverse()
print("".join(b))
# Out:
# 654321

# %% [markdown]
# ## W3A2
# Hoán đổi hai số không sd biến tạm thời
# Sử dụng phép toán XOR bitwise để hoán đổi giá trị của hai biến.

# %%
a, b = map(int, input().split())
a = a^b
b = a^b
a = a^b
print(a, b)
# Out:
# 56 34

# %% [markdown]
# ### W3A3
# Kiểm tra xem một số có phải là lũy thừa của 2 hay không
# ###### Sử dụng các toán tử bitwise để xác định xem một số có phải là lũy thừa của 2 hay không.
# ###### Gợi ý: Đối với lũy thừa của 2, n & (n-1) == 0 (AND)

# %%
a = int(input())
if a & (a-1) ==0:
    print(f"{a} là lũy thừa của 2")
else:
    print(f"{a} không phải là lũy thừa của 2")
# Out:
# 80 không phải là lũy thừa của 2

# %% [markdown]
# ### W3A4
# viết chương trình chia một số m cho n, kết quả thu được làm tròn xuống

# %%
m, n = map(float, input().split())

print(m//n)
# Out:
# 0.0

# %% [markdown]
# ### W3A5
# viết chương trình chia một số m cho n, kết quả thu được làm tròn lên

# %%
m, n = map(int, input().split())
if m % n == 0:
    print(m//n)
else:
    print(m//n+1)
# Out:
# 2

# %% [markdown]
# ### W3A6
# Nhập vào một số nguyên dương x, bạn hãy kiểm tra xem x là số chẵn hay lẻ. Nếu x là số chẵn, in ra "Even". Nếu x
# là số lẻ, in ra "Odd".

# %%
x = int(input())
if x & 1 ==0:
    print("Even")
else:
    print("Odd")
# Out:
# Odd

# %% [markdown]
# ### W3A7:
# Nhập vào hai số nguyên a, b. Nếu cả hai số a, b đều âm thì in ra "Yes", ngược lại in ra "No"

# %%
a, b = map(int, input().split())
if max(a, b)<0:
    print("YES")
else:
    print("NO")
# Out:
# NO

# %% [markdown]
# ### W3A8
# [Longer string]
# Nhập vào hai chuỗi a, b gồm các chữ cái thường. In ra "True" nếu chuỗi a dài hơn chuỗi b. Ngược lại in ra "False"

# %%
a = input()
b = input()
if a.islower() and b.islower():
    if len(a)   > len(b):
        print("True")
    else:        print("False")
else:
    print("Không phải là chuỗi thường")
# Out:
# False

# %% [markdown]
# ### W3A9
# Nhập vào 3 số nguyên dương a, b, c. Kiểm tra xem a, b, c có cấu thành độ dài cạnh của 1 tam giác được không.
# Nếu a, b, c cấu tạo thành được một tam giác, in ra "Yes". Ngược lại in ra "No".

# %%
a, b, c = map(int, input().split())
if min (a, b, c) > 0 and a+b>c and a+c>b and b+c>a:
    print("YES")
else:
    print("NO")
# Out:
# YES

# %% [markdown]
# ### W3A10
# Nhập vào 4 số nguyên. In ra màn hình số nguyên lớn nhất trong 4 số.

# %%
a, b, c, d = map(int, input().split())
print(max(a, b, c, d))
# Out:
# 10

# %% [markdown]
# ### W3A11
# [Phân loại tam giác]
# Nhập vào 3 số nguyên dương a,b,c là độ dài 3 cạnh của một tam giác. Kiểm tra 3 số đã nhập có tạo thành một tam giác hợp
# lệ hay không. Nếu không in ra "Không phải tam giác". Nếu có, phân loại tam giác đó là "Tam giác đều", "Tam giác cân", hay
# "Tam giác thường".

# %%
a, b ,c = map(int, input().split())
if min (a, b, c) > 0 and a+b>c and a+c>b and b+c>a:
    if a == b == c:
        print("Tam giác đều")   
    elif a == b or a == c or b == c:
        print("Tam giác cân")
    elif a**2 + b**2 == c**2 or a**2 + c**2 == b**2 or b**2 + c**2 == a**2:
        print("Tam giác vuông")
    else:
        print("Tam giác thường")
if min (a, b, c) <= 0 or a+b<=c or a+c<=b or b+c<=a:
    print("Không phải là tam giác")
# Out:
# Tam giác vuông

# %% [markdown]
# ### W3A12
# [Kiểm tra năm nhuận]
# Nhập vào một số nguyên dương n là số năm, kiểm tra xem năm đó có phải là năm nhuận hay không. Năm nhuận là năm
# chia hết cho 4 nhưng không chia hết cho 100, hoặc chia hết cho 400. Nếu là năm nhuận in ra "Yes", nếu không in ra "No"

# %%
n = int(input())
if n > 0:
    if (n % 4 == 0 and n % 100 != 0) or n % 400 == 0:
        print(f"{n} là năm nhuận")
    else:
        print(f"{n} không phải là năm nhuận")
else:
    print("Năm không hợp lệ")

# %% [markdown]
# ### W3A13
# [Tính tiền điện]
# Nhập vào số kWh điện tiêu thụ. Tính tiền điện theo các bậc sau:
# - 0-50 kWh: 1500đ/kWh
# - 51-100 kWh: 2000đ/kWh
# - 100 kWh: 3000đ/kWh

# %%
a = int(input("Số kWh tiêu thụ: "))
if 0 < a <= 50:
    cost = a * 1500
elif 51 <= a <= 100:
    cost = 50 * 1500 + (a - 50) * 2000
elif 101 <= a:
    cost = 50 * 1500 + 50 * 2000 + (a - 100) * 3000
    print(f"Số tiền phải trả: {cost} VND")
else:
    print("Số kWh không hợp lệ")
# Out:
# Số kWh không hợp lệ

# %% [markdown]
# ### W3A14
# [Giải phương trình bậc nhất]
# Nhập vào hai số thực a và b của phương trình ax + b = 0. Tìm và in ra nghiệm của phương trình, kết quả làm tròn đến số
# thập phân thứ 2. In ra "Vô nghiệm" hoặc "Vô số nghiệm" trong trường hợp tương ứng.

# %%
a, b = map(int, input().split())
if a==0:
    if b==0:
        print("Phương trình có vô số nghiệm")
    else:
        print("Phương trình vô nghiệm")
else:
    x = -b/a
    print(f"Phương trình có nghiệm x = {x}")

# %% [markdown]
# ### W3A15
# [Xếp loại học lực]
# Nhập vào điểm trung bình của một học sinh và in ra học lực của học sinh đó. Xếp loại học lực theo quy tắc:
# - >= 8.0: Giỏi
# - >= 6.5: Khá
# - >= 5.0: Trung bình
# - < 5.0: Yếu

# %%
k = float(input(" điểm trung bình: "))
if 0 <= k < 5:
    print("Yếu")
elif 5 <= k < 6.5:
    print("Trung bình")
elif 6.5 <= k < 8:
    print("Khá")
elif 8 <= k <= 10:
    print("Giỏi")
else:
    print("Điểm không hợp lệ")
# Out:
# Giỏi

# %% [markdown]
# ### W3A16
# Nhập vào một số thực: in ra kết quả làm tròn lên ,tròn xuống, làm tròn tới số nguyên gần nhất (không được sử dụng hàm
# sẵn có của pyton). Các kết quả cách nhau một dấu cách

# %%
a = float(input())
thap_phan_a = a - int(a)
if  thap_phan_a == 0:
    tron_xuong_a= tron_len_a =tron_gan_a=int(a)
else:
    if a>=0:
        tron_xuong_a = int(a)
        tron_len_a = int(a) + 1
        if thap_phan_a <= 0.5:
            tron_gan_a = tron_xuong_a
        else:
            tron_gan_a = tron_len_a
    else:
        tron_xuong_a = int(a) - 1
        tron_len_a = int(a)
        if thap_phan_a > -0.5:
            tron_gan_a = tron_len_a
        else:
            tron_gan_a = tron_xuong_a 
print(f"{tron_len_a} {tron_xuong_a} {tron_gan_a}")
# Out:
# 8 7 7

# %% [markdown]
# ### W3A17
# Cấp số nhân
# Cho 4 số a, b, c, d. Hãy kiểm tra xem 4 số này có thể theo thứ tự tạo thành 1 cấp số nhân với công bội nguyên theo đúng
# thứ tự a, b, c, d hay không?
# Gợi ý : Tìm công bội (b / a) nếu b chia hết cho a, sau đó lấy b nhân công bội và so sánh vs c, c nhân công bội và so sánh vs
# d.

# %%
a, b, c, d = map(int, input().split())
q = b/a
if q==c/b and q==d/c:
    print("YES")
else:
    print("NO")
# Out:
# NO
